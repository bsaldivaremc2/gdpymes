# %% [markdown]
# # Classification

# %%
import importlib
import class_metrics
importlib.reload(class_metrics)
# Out:
# <module 'class_metrics' from 'c:\\Users\\bsald\\Documents\\curso_ml\\gdpymes\\march2026\\module2\\class_metrics.py'>

# %%
y_true = [0,1,1,0,1,0,1,0]
y_prob = [0.1,0.9,0.8,0.3,0.7,0.2,0.6,0.4]

report = class_metrics.classification_report_with_plots(
    y_true,
    y_prob,
    prob_threshold=0.5
)
report
# Out:
#         metric     value
# 0     accuracy  1.000000
# 1    precision  1.000000
# 2       recall  1.000000
# 3     f1_score  1.000000
# 4  specificity  1.000000
# 5      roc_auc  1.000000
# 6       pr_auc  1.000000
# 7     log_loss  0.299001

# %% [markdown]
# ## Regression

# %%
import reg_metrics
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]

report = reg_metrics.regression_report_with_plots(
    y_true,
    y_pred
)
report
# Out:
#                   metric     value
# 0                    mae  0.500000
# 1                    mse  0.375000
# 2                   rmse  0.612372
# 3                     r2  0.948608
# 4     explained_variance  0.957173
# 5  median_absolute_error  0.500000
