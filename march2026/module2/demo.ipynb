# %% [markdown]
# https://colab.research.google.com/drive/1v2KWkCO_S9T8uYIX0S1Y11kS9XaTFWgu?usp=sharing

# %% [markdown]
# # Classification

# %%
import importlib
import class_metrics
importlib.reload(class_metrics)

# %%
y_true = [0,1,1,0,1,0,1,0]
y_prob = [0.1,0.9,0.8,0.3,0.7,0.2,0.6,0.4]

report = class_metrics.classification_report_with_plots(
    y_true,
    y_prob,
    prob_threshold=0.5
)
report

# %% [markdown]
# ## Regression

# %%
import reg_metrics
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]

report = reg_metrics.regression_report_with_plots(
    y_true,
    y_pred
)
report
